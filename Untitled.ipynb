# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\sawanta\Downloads\NewsandSentimentsAnalysis_18112022.xlsx") 
df
# Out:
#            Date                                                URL  \
# 0    18-11-2022  https://economictimes.indiatimes.com/news/econ...
# 1    18-11-2022  https://economictimes.indiatimes.com/news/econ...
# 2    18-11-2022  https://economictimes.indiatimes.com/industry/...
# 3    18-11-2022  https://economictimes.indiatimes.com/markets/s...
# 4    18-11-2022  https://economictimes.indiatimes.com/small-biz...
# ..          ...                                                ...
# 230  18-11-2022  https://www.livemint.com//technology/tech-news...
# 231  18-11-2022  https://www.livemint.com//news/india/cost-must...
# 232  18-11-2022  https://www.livemint.com//market/commodities/g...
# 233  18-11-2022  https://www.livemint.com//market/ipo/five-star...
# 234  18-11-2022  https://timesofindia.indiatimes.com/india/some...
#
#             Category                                           Headline  \
# 0       news/economy  RBI may have bought $8 billion from market in ...
# ...

# %%
df['News'] = df['News'].apply(lambda x: x.split('  "[]"')[0])
df['News'] = df['News'].apply(lambda x: x.split('[class="or"]')[0])
df['News'] = df['News'].apply(lambda x: x.split('["Rs 386-407"]')[0])

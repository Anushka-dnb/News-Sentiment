# %%
pip install newspaper3k
# Out:
# Requirement already satisfied: newspaper3k in c:\users\sawanta\anaconda3\lib\site-packages (0.2.8)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: requests>=2.10.0 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (2.27.1)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (4.8.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (6.0)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (3.2.0)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (9.0.1)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (6.0.10)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (4.11.1)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (3.7)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sawanta\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.3.1)
# Requirement already satisfied: six in c:\users\sawanta\anaconda3\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\sawanta\anaconda3\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: joblib in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: click in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.64.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.26.11)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2022.6.15)
# Requirement already satisfied: requests-file>=1.4 in c:\users\sawanta\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\sawanta\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.6.0)
# Requirement already satisfied: colorama in c:\users\sawanta\anaconda3\lib\site-packages (from tqdm->nltk>=3.2.1->newspaper3k) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)

# %%
import pandas as pd
import newspaper
from newspaper import Article
import time
from time import sleep
from datetime import date
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

start_time = time.time()
dte=date.today()
dte1=dte.strftime("%d%m%Y")
date=dte.strftime("%d-%m-%Y")

# output file path
path="C:/Users/sawanta/OneDrive - Dun and Bradstreet/Desktop/Work Files/News/NewsandSentimentsAnalysis_29Sept_HT.xlsx"
wb=pd.ExcelWriter(path)
cols = ['Date', 'URL', 'Category', 'Headline', 'News']
datalists = dict()
for item in cols:
    datalists[item] = []

# News paper link    
url="https://economictimes.indiatimes.com"

try:
    pg=requests.get(url, verify=False)
    soup=BeautifulSoup(pg.content, 'lxml')
    prtify=soup.prettify()
    link=soup.find_all("a")
    for lnk in link:
        href=lnk.get('href')
        if href is None:
            continue
        if "/articleshow/" in href:
            if "/hindi/" not in href:
                if "/news/economy/" in href:
                    news=href
                elif "/markets/" in href:
                    if "/expert-view/" not in href:
                        news=href
                elif "/Small-biz/" in href:
                    news=href
                elif "/industry/" in href:
                    if "entertainment" not in href:
                        if "electronics" not in href:
                            if "/advertising/" not in href:
                                news=href
                elif "/tech/ites/" in href:
                    news=href
                elif "/small-biz/" in href:
                    news=href
                else:
                    continue
                if "https" not in news:
                    news=url+news
                    #print('URL-',news)
                    # Appending data into datalists
                    datalists['URL'].append(news)
                    datalists['Date'].append(date)
                    cat1=news.split(".com")[1]
                    cat2=cat1.split("/")
                    cat_fin=cat2[1]+"/"+cat2[2]#+"/"+cat2[3]print("Category: "+cat_fin)
                    # Appending data into datalists
                    datalists['Category'].append(cat_fin)
                    #print('Category-',cat_fin)
                    arti=Article(news)
                    try:
                        pg2=requests.get(news, verify=False)
                        soup2=BeautifulSoup(pg2.content, 'lxml')
                        prtify2=soup2.prettify()
                        head=prtify2.split('"headline": "')[1]
                        headline=head.split('"description":')[0]
                        headline=headline.rstrip().strip('",')
                        #print('headline')
                        datalists['Headline'].append(headline)
                        arti=prtify2.split('"articleBody":"')[1]
                        txt=arti.split('"image": {')[0]
                        txt=txt.rstrip().strip('",')
                        # Appending data into datalists
                        datalists['News'].append(txt)
                        print('Article')
                    except:
                        pass
                else:
                    print('Without HTTP -',news)
except:
    pass
# Out:
# Article
# Article
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/multiple-triggers-to-drive-rally-in-this-tata-group-stock-but-upside-may-be-capped-heres-why/articleshow/94529233.cms
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/multiple-triggers-to-drive-rally-in-this-tata-group-stock-but-upside-may-be-capped-heres-why/articleshow/94529233.cms
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/small-biz/sme-sector/schneider-electric-lays-foundation-of-its-new-smart-factory-in-telangana/articleshow/94529941.cms
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/industry/transportation/airlines-/-aviation/fatigue-among-pilots-in-growing-civil-aviation-space/articleshow/94530725.cms
# Without HTTP - https://economictimes.indiatimes.com/industry/transportation/airlines-/-aviation/fatigue-among-pilots-in-growing-civil-aviation-space/articleshow/94530725.cms
# Without HTTP - https://economictimes.indiatimes.com/industry/transportation/airlines-/-aviation/fatigue-among-pilots-in-growing-civil-aviation-space/articleshow/94530725.cms
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/industry/healthcare/biotech/pharmaceuticals/udaan-starts-multiple-deliveries-per-day-for-pharmacies-in-six-cities/articleshow/94534896.cms
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/189-million-boost-adani-enterprises-to-get-seat-in-nifty-on-friday/articleshow/94523375.cms
# Article
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/these-28-stocks-zoom-up-to-70-in-q2-do-you-own-any/articleshow/94526240.cms
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/these-28-stocks-zoom-up-to-70-in-q2-do-you-own-any/articleshow/94526240.cms
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/these-28-stocks-zoom-up-to-70-in-q2-do-you-own-any/articleshow/94526240.cms
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/news/economy/policy/it-hardware-pli-purse-may-zoom-2-5-times-to-rs-19000-crore/articleshow/94522230.cms
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/industry/telecom/clear-dues-or-lose-tower-access-indus-towers-to-vodafone-idea/articleshow/94492219.cms
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/ace-investor-rakesh-jhunjhunwala-passes-away-at-62/articleshow/93551064.cms
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/dalal-street-week-ahead-nifty-must-take-out-17800-level-for-any-meaningful-rally/articleshow/93542523.cms
# Without HTTP - https://economictimes.indiatimes.com/industry/banking/finance/banking/anshu-jain-former-co-ceo-of-deutsche-bank-passes-away-after-five-year-cancer-battle/articleshow/93544494.cms
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/rakesh-jhunjhunwala-holdings-32-stocks-gave-big-bull-a-rs-32000-crore-portfolio/articleshow/93554791.cms
# Without HTTP - https://economictimes.indiatimes.com/industry/energy/oil-gas/us-says-india-hid-russian-origin-of-fuel-shipped-to-us/articleshow/93541112.cms
# Without HTTP - https://economictimes.indiatimes.com/news/economy/policy/what-india-economy-will-achieve-in-the-next-five-years/articleshow/93547192.cms
# Without HTTP - https://economictimes.indiatimes.com/industry/cons-products/garments-/-textiles/trident-founder-rajinder-gupta-to-step-down/articleshow/93461375.cms
# Without HTTP - https://economictimes.indiatimes.com/news/economy/agriculture/rice-acreage-down-13-till-aug-5-due-to-rain-shortfall/articleshow/93439236.cms
# Without HTTP - https://economictimes.indiatimes.com/news/economy/agriculture/rice-acreage-down-13-till-aug-5-due-to-rain-shortfall/articleshow/93439236.cms
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/corporate-radar-coal-india-ioc-to-turn-ex-dividend-apollo-hospitals-q1-results-agms-and-more/articleshow/93490735.cms
# Without HTTP - https://economictimes.indiatimes.com/small-biz/trade/exports/insights/low-growth-high-inflation-world-faces-increasingly-challenging-global-environment/articleshow/93551847.cms
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news/us-inflation-jumped-7-5-in-the-past-year-a-40-year-high/articleshow/89484170.cms

# %%
## Final Block of code - keep as it is
data = pd.DataFrame.from_dict(datalists, orient='index')
data = data.transpose()
data.to_excel(wb, sheet_name="Sheet1", index=False)
wb.save()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 202.75834584236145 seconds ---

# %%
data
# Out:
#            Date                                                URL  \
# 0    29-09-2022  https://economictimes.indiatimes.com/news/econ...
# 1    29-09-2022  https://economictimes.indiatimes.com/industry/...
# 2    29-09-2022  https://economictimes.indiatimes.com/industry/...
# 3    29-09-2022  https://economictimes.indiatimes.com/industry/...
# 4    29-09-2022  https://economictimes.indiatimes.com/markets/s...
# ..          ...                                                ...
# 102  29-09-2022  https://economictimes.indiatimes.com/news/econ...
# 103  29-09-2022  https://economictimes.indiatimes.com/news/econ...
# 104  29-09-2022  https://economictimes.indiatimes.com/markets/c...
# 105  29-09-2022  https://economictimes.indiatimes.com/markets/s...
# 106  29-09-2022  https://economictimes.indiatimes.com/markets/s...
#
#                 Category                                           Headline  \
# 0           news/economy  Govt hikes interest rate on small savings sche...
# 1          industry/auto  Centre extends deadline for mandatory implemen...
# 2       industry/telecom  Fake identity on OTT, SIM may lead to one year...
# 3          industry/auto  Carmakers on road to log record dispatches in ...
# 4         markets/stocks  Multiple triggers to drive rally in this Tata ...
# ..                   ...                                                ...
# 102         news/economy  India a 'star' among emerging market economies...
# 103         news/economy  Government approves 22nd tranche of electoral ...
# 104  markets/commodities  Gold rate today: Yellow metal gains some stren...
# 105       markets/stocks  Stocks to buy or sell today: 6 short-term trad...
# 106       markets/stocks  Multibagger smallcap stock to trade ex-split o...
#
#                                                   News
# 0    The Central Government has revised the rate of...
# 1    Union Road Transport & Highways Minister Nitin...
# 2    Giving fake documents to get a mobile SIM card...
# 3    Mumbai: India's automakers are set to report t...
# 4    Service related sectors have got their mojo ba...
# ..                                                 ...
# 102  S&P Global Ratings on Thursday said rising rat...
# 103  Ahead of assembly elections in Gujarat and Him...
# 104  Gold prices showed some signs of recovery in I...
# 105  The Indian market opened higher on Thursday tr...
# 106  Shares of Maximus International will trade ex-...
#
# [107 rows x 5 columns]

# %%
import pandas as pd
import newspaper
from newspaper import Article
import time
from time import sleep
from datetime import date
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

start_time = time.time()
dte=date.today()
dte1=dte.strftime("%d%m%Y")
date=dte.strftime("%d-%m-%Y")

# output file path
path="C:/Users/sawanta/OneDrive - Dun and Bradstreet/Desktop/Work Files/News/NewsandSentimentsAnalysis_29Sept-.xlsx"
wb=pd.ExcelWriter(path)
cols = ['Date', 'URL', 'Category', 'Headline', 'News']
datalists = dict()
for item in cols:
    datalists[item] = []

# News paper link    
url="https://www.business-standard.com/"

try:
    pg=requests.get(url, verify=False)
    soup=BeautifulSoup(pg.content, 'lxml')
    prtify=soup.prettify()
    link=soup.find_all('a')
    for lnk in link:
        href=lnk.get('href')
        if href is None:
            continue
        elif ".html" in href:
            if "/finance/" in href:
                news=href
                cat="finance"
            elif "/international/" in href:
                news=href
                cat="international"
            elif "/technology/" in href:
                news=href
                cat="technology"
            elif "/economy-policy/" in href:
                news=href
                cat="economy-policy"
            elif "/current-affairs/" in href:
                news=href
                cat="/current-affairs"
            elif "/companies/" in href:
                news=href
                cat="/companies"
            elif "/automobile/" in href:
                news= href
                cat="/automobile"
            else:
                continue
        else:
            continue
        if "http" not in news:
            news=url+news
            datalists['URL'].append(news)
            datalists['Date'].append(date)
            cat1=news.split(".com")[1]
            cat2=cat1.split("/")
            cat_fin=cat2[1]+"/"+cat2[2]#+"/"+cat2[3]print("Category: "+cat_fin)
            # Appending data into datalists
            datalists['Category'].append(cat_fin)
            #print('Category-',cat_fin)
            arti=Article(news)
            try:
                pg2=requests.get(news, verify=False)
                soup2=BeautifulSoup(pg2.content, 'lxml')
                prtify2=soup2.prettify()
                head=prtify2.split('"headline": "')[1]
                headline=head.split('"description":')[0]
                headline=headline.rstrip().strip('",')
                #print('headline')
                datalists['Headline'].append(headline)
                arti=prtify2.split('"articleBody":"')[1]
                txt=arti.split('"image": {')[0]
                txt=txt.rstrip().strip('",')
                # Appending data into datalists
                datalists['News'].append(txt)
                print('Article')
            except:
                pass
        else:
            print('Without HTTP -',news)
except:
    pass
# Out:
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article
# Article

# %%
## Final Block of code - keep as it is
data1 = pd.DataFrame.from_dict(datalists, orient='index')
data1 = data1.transpose()
data1.to_excel(wb, sheet_name="Sheet1", index=False)
wb.save()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 178.64309167861938 seconds ---

# %%
data1
# Out:
#            Date                                                URL  Category  \
# 0    29-09-2022  https://www.business-standard.com//article/cur...  /article
# 1    29-09-2022  https://www.business-standard.com//article/int...  /article
# 2    29-09-2022  https://www.business-standard.com//article/eco...  /article
# 3    29-09-2022  https://www.business-standard.com//article/eco...  /article
# 4    29-09-2022  https://www.business-standard.com//article/eco...  /article
# ..          ...                                                ...       ...
# 110  29-09-2022  https://www.business-standard.com//article/cur...  /article
# 111  29-09-2022  https://www.business-standard.com//article/eco...  /article
# 112  29-09-2022  https://www.business-standard.com//article/cur...  /article
# 113  29-09-2022  https://www.business-standard.com//article/cur...  /article
# 114  29-09-2022  https://www.business-standard.com//article/cur...  /article
#
#                                               Headline  \
# 0    ED freezes OctaFx Tradings bank balance of Rs ...
# 1    US economy drops at 0.6% annual rate from Apri...
# 2    Govt lowers borrowing target for FY23; to borr...
# 3    Indias current account deficit widens to 2.8% ...
# 4    A shift towards indigenisation: Make in India ...
# ..                                                 ...
# 110  Demand for 3-bedroom homes higher than other c...
# 111  RBI MPC: Experts see a 50 bps hike, pressure o...
# 112  Astronomers map distances in the largest-ever ...
# 113  Earth aims DART to knock asteroid off course; ...
# 114  UP govt takes cognizance as over 2 mn cattle a...
#
#                                                   News
# 0    The Enforcement Directorate ED on Thursday sai...
# 1    Battered by surging consumer prices and rising...
# 2    A day after doling out Rs 44762 crore for free...
# 3    India39s current account deficit a key indicat...
# 4    An analysis of defence capital expenditure cap...
# ..                                                 ...
# 110                                               None
# 111                                               None
# 112                                               None
# 113                                               None
# 114                                               None
#
# [115 rows x 5 columns]

# %%
import pandas as pd
import newspaper
from newspaper import Article
import time
from time import sleep
from datetime import date
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

start_time = time.time()
dte=date.today()
dte1=dte.strftime("%d%m%Y")
date=dte.strftime("%d-%m-%Y")

# output file path
path="C:/Users/sawanta/OneDrive - Dun and Bradstreet/Desktop/Work Files/News/NewsandSentimentsAnalysis_29Sept-.xlsx"
wb=pd.ExcelWriter(path)
cols = ['Date', 'URL', 'Category', 'Headline', 'News']
datalists = dict()
for item in cols:
    datalists[item] = []

# News paper link    
url="https://www.moneycontrol.com/news/"

try:
    pg=requests.get(url, verify=False)
    soup=BeautifulSoup(pg.content, 'lxml')
    prtify=soup.prettify()
    link=soup.find_all('a')
    for lnk in link:
        href=lnk.get('href')
        if href is None:
            continue
        elif ".html" in href:
            if "/finance/" in href:
                news=href
                cat="finance"
            elif "/international/" in href:
                news=href
                cat="international"
            elif "/technology/" in href:
                news=href
                cat="technology"
            elif "/economy-policy/" in href:
                news=href
                cat="economy-policy"
            elif "/current-affairs/" in href:
                news=href
                cat="/current-affairs"
            elif "/companies/" in href:
                news=href
                cat="/companies"
            elif "/automobile/" in href:
                news= href
                cat="/automobile"
            else:
                continue
        else:
            continue
        if "http" not in news:
            news=url+news
            datalists['URL'].append(news)
            datalists['Date'].append(date)
            cat1=news.split(".com")[1]
            cat2=cat1.split("/")
            cat_fin=cat2[1]+"/"+cat2[2]#+"/"+cat2[3]print("Category: "+cat_fin)
            # Appending data into datalists
            datalists['Category'].append(cat_fin)
            #print('Category-',cat_fin)
            arti=Article(news)
            try:
                pg2=requests.get(news, verify=False)
                soup2=BeautifulSoup(pg2.content, 'lxml')
                prtify2=soup2.prettify()
                head=prtify2.split('"headline": "')[1]
                headline=head.split('"description":')[0]
                headline=headline.rstrip().strip('",')
                #print('headline')
                datalists['Headline'].append(headline)
                arti=prtify2.split('"articleBody":"')[1]
                txt=arti.split('"image": {')[0]
                txt=txt.rstrip().strip('",')
                # Appending data into datalists
                datalists['News'].append(txt)
                print('Article')
            except:
                pass
        else:
            print('Without HTTP -',news)
except:
    pass
# Out:
# Without HTTP - https://www.moneycontrol.com/news/technology/centre-orders-blocking-67-porn-websites-9252031.html
# Without HTTP - https://www.moneycontrol.com/news/technology/centre-orders-blocking-67-porn-websites-9252031.html
# Without HTTP - https://www.moneycontrol.com/news/technology/centre-orders-blocking-67-porn-websites-9252031.html
# Without HTTP - https://www.moneycontrol.com/news/automobile/will-work-with-residential-hubs-to-provide-common-ev-charging-spots-tata-motors-md-9252001.html
# Without HTTP - https://www.moneycontrol.com/news/automobile/will-work-with-residential-hubs-to-provide-common-ev-charging-spots-tata-motors-md-9252001.html
# Without HTTP - https://www.moneycontrol.com/news/photos/automobile/in-pics-bmw-launched-m8-competition-50-jahre-m-edition-in-india-at-rs-2-55-crore-9251391.html
# Without HTTP - https://www.moneycontrol.com/news/photos/automobile/in-pics-bmw-launched-m8-competition-50-jahre-m-edition-in-india-at-rs-2-55-crore-9251391.html
# Without HTTP - https://www.facebook.com/sharer/sharer.php?u=https://www.moneycontrol.com/news/photos/automobile/in-pics-bmw-launched-m8-competition-50-jahre-m-edition-in-india-at-rs-2-55-crore-9251391.html
# Without HTTP - https://twitter.com/home?status=https://www.moneycontrol.com/news/photos/automobile/in-pics-bmw-launched-m8-competition-50-jahre-m-edition-in-india-at-rs-2-55-crore-9251391.html
# Without HTTP - https://plus.google.com/share?url=https://www.moneycontrol.com/news/photos/automobile/in-pics-bmw-launched-m8-competition-50-jahre-m-edition-in-india-at-rs-2-55-crore-9251391.html
# Without HTTP - https://www.moneycontrol.com/news/photos/technology/amazon-great-indian-festival-here-are-our-picks-for-best-deals-on-laptops-9250651.html
# Without HTTP - https://www.moneycontrol.com/news/photos/technology/amazon-great-indian-festival-here-are-our-picks-for-best-deals-on-laptops-9250651.html
# Without HTTP - https://www.moneycontrol.com/news/automobile/hero-motocorp-launches-festive-campaign-to-offer-easy-financing-schemes-exchange-bonus-and-more-9234071.html
# Without HTTP - https://www.moneycontrol.com/news/automobile/hero-motocorp-launches-festive-campaign-to-offer-easy-financing-schemes-exchange-bonus-and-more-9234071.html
# Without HTTP - https://www.moneycontrol.com/news/technology/airtel-launches-end-to-end-home-surveillance-solution-xsafe-check-subscription-charge-features-and-more-9233171.html
# Without HTTP - https://www.moneycontrol.com/news/technology/airtel-launches-end-to-end-home-surveillance-solution-xsafe-check-subscription-charge-features-and-more-9233171.html
# Without HTTP - https://www.moneycontrol.com/news/technology/airtel-and-ibm-partner-to-bring-secured-edge-cloud-services-to-india-9176561.html
# Without HTTP - https://www.moneycontrol.com/news/technology/airtel-and-ibm-partner-to-bring-secured-edge-cloud-services-to-india-9176561.html
# Without HTTP - https://www.moneycontrol.com/news/photos/automobile/in-pics-bmw-launched-m8-competition-50-jahre-m-edition-in-india-at-rs-2-55-crore-9251391.html
# Without HTTP - https://www.moneycontrol.com/news/photos/automobile/in-pics-bmw-launched-m8-competition-50-jahre-m-edition-in-india-at-rs-2-55-crore-9251391.html
# Without HTTP - https://www.moneycontrol.com/news/automobile/hero-motocorp-to-invest-about-rs-490-crore-in-zero-motorcycles-to-develop-e-bikes-9251941.html
# Without HTTP - https://www.moneycontrol.com/news/automobile/hero-motocorp-to-invest-about-rs-490-crore-in-zero-motorcycles-to-develop-e-bikes-9251941.html

# %%
## Final Block of code - keep as it is
data2 = pd.DataFrame.from_dict(datalists, orient='index')
data2 = data2.transpose()
data2.to_excel(wb, sheet_name="Sheet1", index=False)
wb.save()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 7.629836559295654 seconds ---

# %%
data2
# Out:
# Empty DataFrame
# Columns: [Date, URL, Category, Headline, News]
# Index: []

# %%
frames = [data,data1]
new_df = pd.concat(frames)
new_df=new_df.dropna(subset = 'News')
new_df
# Out:
#            Date                                                URL  \
# 0    29-09-2022  https://economictimes.indiatimes.com/news/econ...
# 1    29-09-2022  https://economictimes.indiatimes.com/industry/...
# 2    29-09-2022  https://economictimes.indiatimes.com/industry/...
# 3    29-09-2022  https://economictimes.indiatimes.com/industry/...
# 4    29-09-2022  https://economictimes.indiatimes.com/markets/s...
# ..          ...                                                ...
# 105  29-09-2022  https://www.business-standard.com//article/int...
# 106  29-09-2022  https://www.business-standard.com//article/int...
# 107  29-09-2022  https://www.business-standard.com//article/int...
# 108  29-09-2022  https://www.business-standard.com//article/cur...
# 109  29-09-2022  https://www.business-standard.com//article/com...
#
#              Category                                           Headline  \
# 0        news/economy  Govt hikes interest rate on small savings sche...
# 1       industry/auto  Centre extends deadline for mandatory implemen...
# 2    industry/telecom  Fake identity on OTT, SIM may lead to one year...
# 3       industry/auto  Carmakers on road to log record dispatches in ...
# 4      markets/stocks  Multiple triggers to drive rally in this Tata ...
# ..                ...                                                ...
# 105          /article  US economy drops at 0.6% annual rate from Apri...
# 106          /article  Ford India loss widens to Rs 4,229 cr in FY22,...
# 107          /article  Sterling volatile as PM Truss defends tax-cutt...
# 108          /article  Karnataka 2nd PUC Supplementary result 2022 an...
# 109          /article  We have sold 50% of Mumbai inventory: Puravank...
#
#                                                   News
# 0    The Central Government has revised the rate of...
# 1    Union Road Transport & Highways Minister Nitin...
# 2    Giving fake documents to get a mobile SIM card...
# 3    Mumbai: India's automakers are set to report t...
# 4    Service related sectors have got their mojo ba...
# ..                                                 ...
# 105  Buyer demand for three bedroom homes overtook ...
# 106  In the upcoming Monetary Policy Committee MPC ...
# 107  Astronomers have assembled the largest ever co...
# 108  Today early morning the National Aeronautics a...
# 109  As India is witnessing a surge in the viral Lu...
#
# [217 rows x 5 columns]

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob
import en_core_web_sm 
nlp = en_core_web_sm.load()
nlp.add_pipe('spacytextblob')
import string
punctuations = string.punctuation

test_text = new_df['News']
def spacy_tokenizer(test_text):
    mytokens = nlp(test_text)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    return mytokens

# Basic function to clean the text 
def clean_text(text):     
    return text.strip().lower()

# %%
polarity_score = []

for text in test_text:
  doc = nlp(text)
  polarity = (doc._.polarity)
  polarity_score.append(polarity)

# %%
import numpy as np
new_df['Compound'] = polarity_score
conditions = [
    (new_df['Compound'] > 0.05),
    (new_df['Compound'] < -0.05),
    (new_df['Compound'] >= -0.05) & (new_df['Compound'] <= 0.05)]

values = [1,-1 ,0]

new_df['Sentiment'] = np.select(conditions, values)

# %%
new_df['Sentiment'].value_counts()

# %%
from sklearn.model_selection import train_test_split
# Features and Labels
X = new_df['News'].astype(str)
ylabels = new_df['Sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.3, random_state=42)

# %%
## Count Vectorizer Method 
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
ctmTr = cv.fit_transform(X_train)
X_test_dtm = cv.transform(X_test)

# %%
#Random Forest Method
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, criterion ='entropy', random_state = 0)
model.fit(ctmTr, y_train)
y_pred = model.predict(X_test_dtm)

#Create the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
model.score(X_test_dtm,y_test)

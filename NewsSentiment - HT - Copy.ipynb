# %%
pip install newspaper3k
# Out:
# Requirement already satisfied: newspaper3k in c:\users\sawanta\anaconda3\lib\site-packages (0.2.8)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (4.8.0)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (9.0.1)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (6.0.10)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (3.7)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (3.2.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (4.11.1)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (6.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: requests>=2.10.0 in c:\users\sawanta\anaconda3\lib\site-packages (from newspaper3k) (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sawanta\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.3.1)
# Requirement already satisfied: six in c:\users\sawanta\anaconda3\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\sawanta\anaconda3\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.64.0)
# Requirement already satisfied: joblib in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: click in c:\users\sawanta\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sawanta\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.3)
# Requirement already satisfied: requests-file>=1.4 in c:\users\sawanta\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\sawanta\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.6.0)
# Requirement already satisfied: colorama in c:\users\sawanta\anaconda3\lib\site-packages (from tqdm->nltk>=3.2.1->newspaper3k) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\sawanta\anaconda3\lib\site-packages)

# %%
import pandas as pd
import newspaper
from newspaper import Article
import time
from time import sleep
from datetime import date
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

start_time = time.time()
dte=date.today()
dte1=dte.strftime("%d%m%Y")
date=dte.strftime("%d-%m-%Y")

# output file path
path="C:/Users/sawanta/OneDrive - Dun and Bradstreet/Desktop/Work Files/News/NewsandSentimentsAnalysis_9Sept.xlsx"
wb=pd.ExcelWriter(path)
cols = ['Date', 'URL', 'Category', 'Headline', 'News']
datalists = dict()
for item in cols:
    datalists[item] = []

# News paper link    
url="https://economictimes.indiatimes.com"

try:
    pg=requests.get(url, verify=False)
    soup=BeautifulSoup(pg.content, 'lxml')
    prtify=soup.prettify()
    link=soup.find_all("a")
    for lnk in link:
        href=lnk.get('href')
        if href is None:
            continue
        if "/articleshow/" in href:
            if "/hindi/" not in href:
                if "/news/economy/" in href:
                    news=href
                elif "/markets/" in href:
                    if "/expert-view/" not in href:
                        news=href
                elif "/Small-biz/" in href:
                    news=href
                elif "/industry/" in href:
                    if "entertainment" not in href:
                        if "electronics" not in href:
                            if "/advertising/" not in href:
                                news=href
                elif "/tech/ites/" in href:
                    news=href
                elif "/small-biz/" in href:
                    news=href
                else:
                    continue
                if "https" not in news:
                    news=url+news
                    #print('URL-',news)
                    # Appending data into datalists
                    datalists['URL'].append(news)
                    datalists['Date'].append(date)
                    cat1=news.split(".com")[1]
                    cat2=cat1.split("/")
                    cat_fin=cat2[1]+"/"+cat2[2]#+"/"+cat2[3]print("Category: "+cat_fin)
                    # Appending data into datalists
                    datalists['Category'].append(cat_fin)
                    #print('Category-',cat_fin)
                    arti=Article(news)
                    try:
                        pg2=requests.get(news, verify=False)
                        soup2=BeautifulSoup(pg2.content, 'lxml')
                        prtify2=soup2.prettify()
                        head=prtify2.split('"headline": "')[1]
                        headline=head.split('"description":')[0]
                        headline=headline.rstrip().strip('",')
                        #print('headline')
                        datalists['Headline'].append(headline)
                        arti=prtify2.split('"articleBody":"')[1]
                        txt=arti.split('"image": {')[0]
                        txt=txt.rstrip().strip('",')
                        # Appending data into datalists
                        datalists['News'].append(txt)
                        print('Article')
                    except:
                        pass
                else:
                    print('Without HTTP -',news)
except:
    pass
# Out:
# Article
# Article
# Article
# Article
# Article
# Article
# Without HTTP - https://economictimes.indiatimes.com/markets/stocks/news
-09-2022  https://economictimes.indiatimes.com/news/econ...
# 109  29-09-2022  https://economictimes.indiatimes.com/news/econ...
# 110  29-09-2022  https://economictimes.indiatimes.com/markets/c...
# 111  29-09-2022  https://economictimes.indiatimes.com/markets/s...
# 112  29-09-2022  https://economictimes.indiatimes.com/markets/s...
#
#                 Category                                           Headline  \
# 0        industry/energy  Indian refiners unlikely to pass on gains from...
# 1          industry/auto  Carmakers on road to log record dispatches in ...
# 2           news/economy  India heads for its third half-point hike as r...
# 3       industry/banking  NBFCs stare at a liquidity squeeze amid debt f...
# 4         markets/stocks  Mean reversion indicates fears of 30% dip in N...
# ..                   ...                                                ...
# 108         news/economy  Crop share in India’s agri fell in FY20 from F...
# 109         news/economy  Chief economists' survey puts spotlight on inc...
# 110  markets/commodities  Gold rate today: Yellow metal gains some stren...
# 111       markets/stocks  Stocks to buy or sell today: 6 short-term trad...
# 112       markets/stocks  Multibagger smallcap stock to trade ex-split o...
#
#                                                   News
# 0    A 30% decline in oil prices since early June h...
# 1    Mumbai: India's automakers are set to report t...
# 2    India’s central bank is expected to increase i...
# 3    Non-banking financial companies (NBFCs) are st...
# 4    Pointing out that the visible decoupling of In...
# ..                                                 ...
# 108  The share of crops in India’s agriculture fell...
# 109  Persistently high inflation and consistently f...
# 110  Gold prices showed some signs of recovery in I...
# 111  The Indian market opened higher on Thursday tr...
# 112  Shares of Maximus International will trade ex-...
#
# [113 rows x 5 columns]

# %%
new_df = pd.DataFrame()
new_df['Date'] = data['Date']
new_df['Headline'] = data['Headline']
new_df['URL'] = data['URL']
new_df['Category'] = data['Category']
new_df['News'] = data['News'].astype(str)

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob
import en_core_web_sm 
nlp = en_core_web_sm.load()
nlp.add_pipe('spacytextblob')
import string
punctuations = string.punctuation

test_text = new_df['News']
def spacy_tokenizer(test_text):
    mytokens = nlp(test_text)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    return mytokens

# Basic function to clean the text 
def clean_text(text):     
    return text.strip().lower()

# %%
from textblob import TextBlob

def sentimental(text: str) -> str:
    sentiment = None
    if text:
        text = ''.join(text.split()).strip() # removing empty strings
        blob = TextBlob(text)
        if blob.sentiment.polarity > 0:
            sentiment = 'Positive'
        if blob.sentiment.polarity < 0:
            sentiment = 'Negative'
        if blob.sentiment.polarity == 0:
            sentiment = 'Neutral'
    return sentiment

# %%
polarity_score = []

for text in test_text:
  doc = nlp(text)
  polarity = (doc._.polarity)
  polarity_score.append(polarity)

# %%
import numpy as np
new_df['Compound'] = polarity_score
conditions = [
    (new_df['Compound'] > 0.05),
    (new_df['Compound'] < -0.05),
    (new_df['Compound'] >= -0.05) & (new_df['Compound'] <= 0.05)]

values = [1,-1 ,0]

new_df['Sentiment'] = np.select(conditions, values)
# Out:
#            Date                                           Headline  \
# 0    29-09-2022  Indian refiners unlikely to pass on gains from...
# 1    29-09-2022  Carmakers on road to log record dispatches in ...
# 2    29-09-2022  India heads for its third half-point hike as r...
# 3    29-09-2022  NBFCs stare at a liquidity squeeze amid debt f...
# 4    29-09-2022  Mean reversion indicates fears of 30% dip in N...
# ..          ...                                                ...
# 108  29-09-2022  Crop share in India’s agri fell in FY20 from F...
# 109  29-09-2022  Chief economists' survey puts spotlight on inc...
# 110  29-09-2022  Gold rate today: Yellow metal gains some stren...
# 111  29-09-2022  Stocks to buy or sell today: 6 short-term trad...
# 112  29-09-2022  Multibagger smallcap stock to trade ex-split o...
#
#                                                    URL             Category  \
# 0    https://economictimes.indiatimes.com/industry/...      industry/energy
# 1    https://economictimes.indiatimes.com/industry/...        industry/auto
# 2    https://economictimes.indiatimes.com/news/econ...         news/economy
# 3    https://economictimes.indiatimes.com/industry/...     industry/banking
# 4    https://economictimes.indiatimes.com/markets/s...       markets/stocks
# ..                                                 ...                  ...
# 108  https://economictimes.indiatimes.com/news/econ...         news/economy
# 109  https://economictimes.indiatimes.com/news/econ...         news/economy
# 110  https://economictimes.indiatimes.com/markets/c...  markets/commodities
# 111  https://economictimes.indiatimes.com/markets/s...       markets/stocks
# 112  https://economictimes.indiatimes.com/markets/s...       markets/stocks
#
#                                                   News  Compound  Sentiment
# 0    A 30% decline in oil prices since early June h... -0.012681          0
# 1    Mumbai: India's automakers are set to report t...  0.123837          1
# 2    India’s central bank is expected to increase i...  0.033775          0
# 3    Non-banking financial companies (NBFCs) are st...  0.076198          1
# 4    Pointing out that the visible decoupling of In...  0.002965          0
# ..                                                 ...       ...        ...
# 108  The share of crops in India’s agriculture fell...  0.011765          0
# 109  Persistently high inflation and consistently f...  0.053922          1
# 110  Gold prices showed some signs of recovery in I...  0.099525          1
# 111  The Indian market opened higher on Thursday tr...  0.104293          1
# 112  Shares of Maximus International will trade ex-... -0.122917         -1
#
# [113 rows x 7 columns]

# %%
new_df['Sentiment'].value_counts()
# Out:
#  1    68
#  0    36
# -1     9
# Name: Sentiment, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# Features and Labels
X = new_df['News'].astype(str)
ylabels = new_df['Sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.3, random_state=42)

# %%
## Count Vectorizer Method 
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()

ctmTr = cv.fit_transform(X_train)

X_test_dtm = cv.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

model = LogisticRegression()

model.fit(ctmTr, y_train)

y_pred_class = model.predict(X_test_dtm)

# %%
accuracy_score(y_test, y_pred_class)
# Out:
# 0.7352941176470589

# %%
## Count Vectorizer Method 
from sklearn.feature_extraction.text import TfidfVectorizer

cv_tfidf = TfidfVectorizer()

ctmTr_tfidf = cv_tfidf.fit_transform(X_train)

X_test_dtm_tfidf = cv_tfidf.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

model = LogisticRegression()

model.fit(ctmTr_tfidf, y_train)

y_pred_class = model.predict(X_test_dtm_tfidf)

# %%
accuracy_score(y_test, y_pred_class)
# Out:
# 0.7941176470588235

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, criterion ='entropy', random_state = 0)
model.fit(ctmTr, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
y_pred = model.predict(X_test_dtm)

#Create the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 4,  0,  0],
#        [ 0,  7,  2],
#        [ 0,  0, 21]], dtype=int64)

# %%
model.score(X_test_dtm,y_test)
# Out:
# 0.9411764705882353
